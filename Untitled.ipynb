# %%
import pandas as pd
df = pd.read_csv('final_PINK.csv')
df2 = 
df.merge(df2,ON =)

# %%
df.tail(10)
# Out:
#     country_id traffic_source_level_1 timestamp_month  SEK_IN_FOOD  \
# 818         SE           partnerships         00:00.0        21.38
# 819         SE           partnerships         00:00.0        10.69
# 820         SE           partnerships         00:00.0        16.04
# 821         SE           partnerships         00:00.0         8.91
# 822         SE           partnerships         00:00.0         3.56
# 823         SE           partnerships         00:00.0         8.91
# 824         SE           partnerships         00:00.0         7.12
# 825         SE           partnerships         00:00.0         2.51
# 826         SE           partnerships         00:00.0         3.34
# 827         SE           partnerships         00:00.0         1.67
#
#      SEK_IN_DRINKS  SEK_IN_SNACKS        rate
# 818            NaN           3.72  574.731183
# 819            NaN           6.03  177.280265
# 820            NaN           6.69  239.760837
# ...

# %%
df['rate'] = df['SEK_IN_FOOD']/df['SEK_IN_SNACKS'] *100

# %%
type(df['country_id'][4])
# Out:
# str

# %%
df[['country_id','SEK_IN_FOOD']].groupby(['country_id']).sum()
# Out:
#             SEK_IN_FOOD
# country_id
# BR            139369.00
# DE             56398.24
# DK             18965.22
# ES             10936.12
# FI             36548.77
# FR             74156.75
# GB            312238.12
# IT              5193.91
# MX            232383.91
# NL             75197.10
# NO             48723.18
# SE             53004.51
